# %%
__name__
# Out:
# '__main__'

# %%
__file__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 __file__
#
# NameError: name '__file__' is not defined

# %%
def main():
    print("我是專案檔的主執行檔")
    
if __name__ == "__main__":
    main()
# Out:
# 我是專案檔的主執行檔
