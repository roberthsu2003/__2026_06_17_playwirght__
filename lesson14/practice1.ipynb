# %%
student = {
    "name": "Robert",
    "age": 18
}

# 使用 subscript
print(student["name"])

# 使用 get()
print(student.get("name"))
# Out:
# Robert
# Robert

# %%
student = {
    "name": "Robert",
    "age": 18
}

print(student["score"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 6
#       2     "name": "Robert",
#       3     "age": 18
#       4 }
#       5
# ----> 6 print(student["score"])
#
# KeyError: 'score'

# %%
student = {
    "name": "Robert",
    "age": 18
}

print(student.get("score"))
# Out:
# None

# %%
numbers = [1, 2, 3, 4, 5]

result = []

for n in numbers:
    result.append(n * 2)

print(result)
# Out:
# [2, 4, 6, 8, 10]

# %%
numbers = [1, 2, 3, 4, 5]

result = [n * 2 for n in numbers]

print(result)
# Out:
# [2, 4, 6, 8, 10]
